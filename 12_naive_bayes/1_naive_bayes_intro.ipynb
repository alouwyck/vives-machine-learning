# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-machine-learning/blob/main/12_naive_bayes/1_naive_bayes_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **MACHINE LEARNING FUNDAMENTALS**<br>
# Academiejaar 2023-2024<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # **TOPIC 11: NAIVE BAYES - INTRO**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Download de volgende dataset van Kaggle: https://www.kaggle.com/datasets/bhavikjikadara/fake-news-detection.
#
# De dataset bestaat uit 2 files `'true.csv'` en `'fake.csv` die een groot aantal nieuwsberichten opdelen in correct nieuws en fake news.

# %% [markdown]
# Het zijn twee grote bestanden, dus is het interessanter (en vooral sneller!) om de datasets via de Kaggle API in de Colab omgeving binnen te trekken.

# %% [markdown]
# Maak eerst een kaggle.json file aan via de Kaggle website:
# - inloggen
# - ga naar "My Account" > API section

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Daarna laad je jouw kaggle.json file op in je Colab folder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Verplaats je kaggle.json file naar de .kaggle folder:

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Je kan dit ook met de volgende Python code doen:
#
# ```python
# import os, shutil
# os.mkdir('.kaggle')
# shutil.copyfile('kaggle.json', '.kaggle/kaggle.json')
# os.remove('kaggle.json')
# ```

# %% [markdown]
# Het is wel belangrijk dat je de kaggle package in Colab gaat upgraden, want anders krijg je een foutmelding:

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %% [markdown]
# Je kan nu de dataset downloaden met het volgende commando:

# %%
# !kaggle datasets download -d bhavikjikadara/fake-news-detection

# %% [markdown]
# Dat commando kan je kopiëren via de drie puntjes:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Indien je een 403 foutmelding krijgt, dan moet je de voorwaarden accepteren.

# %% [markdown]
# De dataset unzippen kan eenvoudig met package `shutil`. Vraag desnoods aan ChatGPT hoe je dat moet doen.

# %% [markdown]
# Lees nu de twee files in als DataFrame. Voeg ze samen zodat je één grote tabel krijgt. Vergeet niet om een kolom `'fake'` met de labels toe te voegen, waarbij de fake news berichten label `True` krijgen en de andere `False`!

# %% [markdown]
# Programmeer nu een functie `predict` die voorspelt of een nieuwsbericht fake news is (`True`) of echt nieuws (`False`). Probeer een zo hoog mogelijke nauwkeurigheid te behalen. Maak GEEN gebruik van Scikit-Learn!

# %%
def predict(df):
    # jouw code

# %%
# pas je functie toe op de dataset en print de nauwkeurigheid

# %% [markdown]
# Probeer nu om een hogere nauwkeurigheid te krijgen door gebruik te maken van één van de Scikit-Learn algoritmes die we al hebben gezien tijdens de lessen.

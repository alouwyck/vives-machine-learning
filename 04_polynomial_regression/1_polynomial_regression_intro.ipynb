# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-machine-learning/blob/main/04_polynomial_regression/1_polynomial_regression_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **MACHINE LEARNING FUNDAMENTALS**<br>
# Academiejaar 2022-2023<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # POLYNOMIALE REGRESSIE: INTRO

# %% [markdown]
# ![image.png](data:image/png;base64,...)<br>
# (bron: https://www.hbvl.be/cnt/dmf20220304_95337004)

# %% [markdown]
# ## OPGAVE

# %% [markdown]
# Lees de file "missile.csv" in als Pandas `DataFrame`. De file bevat fictieve data van een raketwerper, nl. tijden en overeenkomstige afstanden en hoogtes, die zijn opgemeten tijdens het afvuren van een raket. Afstanden en hoogtes zijn relatief t.o.v. de lanceerpositie.
#
# Print het dataframe uit en geef ook de belangrijkste statistieken. Maak een scatterplot van de data, waarbij je de (relatieve) hoogte uitzet t.o.v. de (relatieve) afstand. Dus op de x-as komt de afstand, op de y-as de hoogte.
#
# De tekening hieronder stelt het schematisch voor. De raket wordt op een heuvel afgevuurd onder een hoek $\alpha$ met een snelheid $v$ en slaat in op een lager gelegen gedeelte met hoogte gelijk aan 0 m.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Probeer de volgende vragen te beantwoorden:
#
# 1. Op welke (relatieve) hoogte wordt de raket afgevuurd?
# 2. Wat is de maximale (relatieve) hoogte die de raket bereikt?
# 3. Hoeveel seconden na lancering bereikt de raket die maximale hoogte?
# 4. Op welke afstand van de lanceerpositie zal de raket inslaan?
# 5. Hoeveel seconden na lancering zal de raket inslaan?

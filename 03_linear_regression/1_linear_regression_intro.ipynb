# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-machine-learning/blob/main/03_linear_regression/1_linear_regression_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **MACHINE LEARNING FUNDAMENTALS**<br>
# Academiejaar 2023-2024<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # LINEAR REGRESSION: INTRO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## OPGAVE

# %% [markdown]
# Lees de file "zwift.csv" in als Pandas `DataFrame`. De file bevat tijden en overeenkomstige afstanden die zijn opgemeten tijdens een virtuele fietsrit op [Zwift](https://www.zwift.com/).
#
# Print het dataframe uit en geef ook de belangrijkste statistieken. Maak een scatterplot van de data, waarbij je de afstand uitzet t.o.v. de tijd. Dus op de x-as komt de tijd, op de y-as de afstand.
#
# Probeer tenslotte te voorspellen hoeveel kilometers de fietser zal afgelegd hebben na 2 uren fietsen als die aan hetzelfde tempo blijft doorfietsen.
